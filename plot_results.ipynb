# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib widget
# my_script.py

# %%
def plot_results(fname, start_epoch=0, log=True):
    plt.figure(figsize=(12,5)) if not plt.get_fignums() else plt.clf()
    res = pd.read_csv(fname)
    for r in res:
    
        if "val" in r:
            plt.subplot(1,2,1)
            plt.plot(res["epoch"][start_epoch:],res[r][start_epoch:], label=r)
            print(res["epoch"][start_epoch:],res[r][start_epoch:])
        elif "MSE" in r:
            plt.subplot(1,2,2)
            plt.plot(res["epoch"][start_epoch:],res[r][start_epoch:], label=r.replace("metrics/",""))
        elif "metric" in r:
            plt.subplot(1,2,2)
            if log:
                plt.plot(res["epoch"][start_epoch:],1-res[r][start_epoch:], label="1-"+r.replace("metrics/",""))
            else:
                plt.plot(res["epoch"][start_epoch:],res[r][start_epoch:], label=r.replace("metrics/",""))
    plt.subplot(1,2,1)
    plt.xlabel("Epoch")
    plt.ylabel("loss")
    if log:
        plt.yscale("log")
    plt.legend()
    plt.subplot(1,2,2)
    plt.ylabel("metric")
    plt.xlabel("Epoch")
    if log:
        plt.yscale("log")
    plt.legend()
    plt.show()

# %%
plot_results("runs/detect/train/results.csv")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_results("runs/zaxis/train113/results.csv",log=False)
# Out:
# 0    1
# Name: epoch, dtype: int64 0   NaN
# Name: val/box_loss, dtype: float64
# 0    1
# Name: epoch, dtype: int64 0   NaN
# Name: val/cls_loss, dtype: float64
# 0    1
# Name: epoch, dtype: int64 0   NaN
# Name: val/dfl_loss, dtype: float64
# 0    1
# Name: epoch, dtype: int64 0   NaN
# Name: val/zaxis_loss, dtype: float64
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
  shell = IPython.get_ipython()
  In = shell.ev('In')

# %%
In
# Out:
# ['',
#  'import pandas as pd\nimport matplotlib.pyplot as plt',
#  'def plot_results(fname):\n    plt.figure(figsize=(12,5)) if not plt.get_fignums() else plt.clf()\n    res = pd.read_csv(fname)\n    for r in res:\n        if "loss" in r:\n            plt.subplot(1,2,1)\n            plt.plot(res[r], label=r)\n        elif "metric" in r:\n            plt.subplot(1,2,2)\n            plt.plot(res[r], label=r)\n    plt.subplot(1,2,1)\n    plt.yscale("log")\n    plt.legend()\n    plt.subplot(1,2,2)\n    plt.legend()\n    plt.show()',
#  'plot_results("runs/detect/train/results.csv")',
#  'plot_results("runs/zaxis/train63/results.csv")',
#  'def plot_results(fname):\n    plt.figure(figsize=(12,5)) if not plt.get_fignums() else plt.clf()\n    res = pd.read_csv(fname)\n    for r in res:\n        if "loss" in r:\n            plt.subplot(1,2,1)\n            plt.plot(res[r], label=r)\n        elif "MSE" in r:\n            plt.subplot(1,2,2)\n            plt.plot(res[r], label=r)\n        elif "metric" in r:\n            plt.subplot(1,2,2)\n            plt.plot(res[r], label=r)\n    plt.subplot(1,2,1)\n    plt.yscale("log")\n    plt.legend()\n    plt.subplot(1,2,2)\n    plt.legend()\n    plt.show()',
#  'plot_results("runs/zaxis/train63/results.csv")',
#  'def plot_results(fname):\n    plt.figure(figsize=(12,5)) if not plt.get_fignums() else plt.clf()\n    res = pd.read_csv(fname)\n    for r in res:\n        if "loss" in r:\n            plt.subplot(1,2,1)\n            plt.plot(res[r], label=r)\n        elif "MSE" in r:\n            plt.subplot(1,2,2)\n            plt.plot(1-res[r], label=r)\n        elif "metric" in r:\n            plt.subplot(1,2,2)\n            plt.plot(res[r], label=r)\n    plt.subplot(1,2,1)\n    plt.yscale("log")\n    plt.legend()\n    plt.subplot(1,2,2)\n    plt.legend()\n    plt.show()',
#  'plot_results("runs/zaxis/train63/results.csv")',
#  'plot_results("runs/zaxis/train63/results.csv")',
#  'plot_results("runs/zaxis/train63/results.csv")',
#  'def plot_results(fname):\n    plt.figure(figsize=(12,5)) if not plt.get_fignums() else plt.clf()\n    res = pd.read_csv(fname)\n    for r in res:\n        if "loss" in r:\n            plt.subplot(1,2,1)\n            plt.plot(res[r], label=r)\n        elif "MSE" in r:\n            plt.subplot(1,2,2)\n            plt.plot(res[r], label=r)\n        elif "metric" in r:\n            plt.subplot(1,2,2)\n            plt.plot(1-res[r], label=r)\n    plt.subplot(1,2,1)\n    plt.yscale("log")\n    plt.legend()\n    plt.subplot(1,2,2)\n    plt.legend()\n    plt.show()',
#  'def plot_results(fname):\n    plt.figure(figsize=(12,5)) if not plt.get_fignums() else plt.clf()\n    res = pd.read_csv(fname)\n    for r in res:\n        if "loss" in r:\n            plt.subplot(1,2,1)\n            plt.plot(res[r], label=r)\n        elif "MSE" in r:\n            plt.subplot(1,2,2)\n            plt.plot(res[r], label=r)\n        elif "metric" in r:\n            plt.subplot(1,2,2)\n            plt.plot(1-res[r], label=r)\n    plt.subplot(1,2,1)\n    plt.yscale("log")\n    plt.legend()\n    plt.subplot(1,2,2)\n    plt.yscale("log")\n    plt.legend()\n    plt.show()',
#  'plot_results("runs/zaxis/train63/results.csv")',
#  'def plot_results(fname):\n    plt.figure(figsize=(12,5)) if not plt.get_fignums() else plt.clf()\n    res = pd.read_csv(fname)\n    for r in res:\n        if "loss" in r:\n            plt.subplot(1,2,1)\n            plt.plot(res[r], label=r)\n        elif "MSE" in r:\n            plt.subplot(1,2,2)\n            plt.plot(res[r], label=r)\n        elif "metric" in r:\n            plt.subplot(1,2,2)\n            plt.plot(1-res[r], label=r)\n    plt.subplot(1,2,1)\n    plt.xlabel("Epoch")\n    plt.ylabel("loss")\n    plt.yscale("log")\n    plt.legend()\n    plt.subplot(1,2,2)\n    plt.ylabel("1-metric")\n    plt.xlabel("Epoch")\n    plt.yscale("log")\n    plt.legend()\n    plt.show()',
#  'plot_results("runs/detect/train/results.csv")',
#  'plot_results("runs/zaxis/train63/results.csv")',
#  "import pandas as pd\nimport matplotlib.pyplot as plt\nget_ipython().run_line_magic('matplotlib', 'widget')",
#  'plot_results("runs/zaxis/train63/results.csv")',
#  'plot_results("runs/zaxis/train63/results.csv")',
#  'plot_results("runs/detect/train/results.csv")',
#  'plot_results("runs/zaxis/train63/results.csv")',
#  'def plot_results(fname):\n    fig =plt.figure(figsize=(12,5)) if not plt.get_fignums() else plt.clf()\n    res = pd.read_csv(fname)\n    for r in res:\n        if "loss" in r:\n            plt.subplot(1,2,1)\n            plt.plot(res[r], label=r)\n        elif "MSE" in r:\n            plt.subplot(1,2,2)\n            plt.plot(res[r], label=r)\n        elif "metric" in r:\n            plt.subplot(1,2,2)\n            plt.plot(1-res[r], label=r)\n    plt.subplot(1,2,1)\n    plt.xlabel("Epoch")\n    plt.ylabel("loss")\n    plt.yscale("log")\n    plt.legend()\n    plt.subplot(1,2,2)\n    plt.ylabel("1-metric")\n    plt.xlabel("Epoch")\n    plt.yscale("log")\n    plt.legend()\n    return fig',
#  'plot_results("runs/detect/train/results.csv")',
#  'plot_results("runs/zaxis/train63/results.csv")',
#  'def plot_results(fname):\n    plt.figure(figsize=(12,5)) if not plt.get_fignums() else plt.clf()\n    res = pd.read_csv(fname)\n    for r in res:\n        if "loss" in r:\n            plt.subplot(1,2,1)\n            plt.plot(res[r], label=r)\n        elif "MSE" in r:\n            plt.subplot(1,2,2)\n            plt.plot(res[r], label=r)\n        elif "metric" in r:\n            plt.subplot(1,2,2)\n            plt.plot(1-res[r], label=r)\n    plt.subplot(1,2,1)\n    plt.xlabel("Epoch")\n    plt.ylabel("loss")\n    plt.yscale("log")\n    plt.legend()\n    plt.subplot(1,2,2)\n    plt.ylabel("1-metric")\n    plt.xlabel("Epoch")\n    plt.yscale("log")\n    plt.legend()\n    return plt.figure(1)',
#  'plot_results("runs/detect/train/results.csv")',
#  "import pandas as pd\nimport matplotlib.pyplot as plt\nget_ipython().run_line_magic('matplotlib', 'widget')\n# my_script.py\n\nimport json\nimport IPython\n\n\ndef get_cell_idx():\n  shell = IPython.get_ipython()\n  In = shell.ev('In')\n\n  depth = 0\n  while True:\n    try:\n      with open(\n          IPython.extract_module_locals(depth=depth)[1]['__vsc_ipynb_file__'],\n          encoding='utf8') as f:\n        nb = json.load(f)\n        break\n    except ValueError:\n      return None\n    except KeyError:\n      depth += 1\n\n  for idx, cell in enumerate(nb['cells']):\n    if ''.join(cell['source']).strip() == In[-1]:\n      return idx",
#  'plot_results("runs/detect/train/results.csv")\nget_cell_idx()',
#  'plot_results("runs/detect/train/results.csv")\nprint(get_cell_idx())',
#  "shell = IPython.get_ipython()\nIn = shell.ev('In')",
#  'In']
